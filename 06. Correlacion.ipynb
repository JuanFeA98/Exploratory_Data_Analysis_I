# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Datos

# %%
from sklearn.datasets import load_breast_cancer

# %%
df = load_breast_cancer()

# %%
data = df.data
features = df.feature_names

# %%
df = pd.DataFrame(data, columns=features)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
# dtypes: float64(30)
# memory usage: 133.5 KB

# %%
wf = df.iloc[:, :6]

# %%
wf
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness
# 0             0.27760
# 1             0.07864
# 2             0.15990
# 3             0.28390
# 4             0.13280
# ..                ...
# 564           0.11590
# 565           0.10340
# 566           0.10230
# 567           0.27700
# 568           0.04362
#
# [569 rows x 6 columns]

# %%
wf.corr()
# Out:
#                   mean radius  mean texture  mean perimeter  mean area  \
# mean radius          1.000000      0.323782        0.997855   0.987357
# mean texture         0.323782      1.000000        0.329533   0.321086
# mean perimeter       0.997855      0.329533        1.000000   0.986507
# mean area            0.987357      0.321086        0.986507   1.000000
# mean smoothness      0.170581     -0.023389        0.207278   0.177028
# mean compactness     0.506124      0.236702        0.556936   0.498502
#
#                   mean smoothness  mean compactness
# mean radius              0.170581          0.506124
# mean texture            -0.023389          0.236702
# mean perimeter           0.207278          0.556936
# mean area                0.177028          0.498502
# mean smoothness          1.000000          0.659123
# mean compactness         0.659123          1.000000

# %%
sns.heatmap(wf.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = pd.DataFrame(wf.corr().unstack()).reset_index()

# %%
corr.rename(columns={0: 'Correlacion'}).sort_values('Correlacion', ascending=False).reset_index(drop=True)
# Out:
#              level_0           level_1  Correlacion
# 0        mean radius       mean radius     1.000000
# 1       mean texture      mean texture     1.000000
# 2    mean smoothness   mean smoothness     1.000000
# 3          mean area         mean area     1.000000
# 4     mean perimeter    mean perimeter     1.000000
# 5   mean compactness  mean compactness     1.000000
# 6     mean perimeter       mean radius     0.997855
# 7        mean radius    mean perimeter     0.997855
# 8        mean radius         mean area     0.987357
# 9          mean area       mean radius     0.987357
# 10    mean perimeter         mean area     0.986507
# 11         mean area    mean perimeter     0.986507
# 12  mean compactness   mean smoothness     0.659123
# 13   mean smoothness  mean compactness     0.659123
# 14  mean compactness    mean perimeter     0.556936
# 15    mean perimeter  mean compactness     0.556936
# 16  mean compactness       mean radius     0.506124
# 17       mean radius  mean compactness     0.506124
# 18         mean area  mean compactness     0.498502
# 19  mean compactness         mean area     0.498502
# 20      mean texture    mean perimeter     0.329533
# 21    mean perimeter      mean texture     0.329533
# 22      mean texture       mean radius     0.323782
# 23       mean radius      mean texture     0.323782
# 24         mean area      mean texture     0.321086
# 25      mean texture         mean area     0.321086
# 26      mean texture  mean compactness     0.236702
# 27  mean compactness      mean texture     0.236702
# 28   mean smoothness    mean perimeter     0.207278
# 29    mean perimeter   mean smoothness     0.207278
# 30   mean smoothness         mean area     0.177028
# 31         mean area   mean smoothness     0.177028
# 32   mean smoothness       mean radius     0.170581
# 33       mean radius   mean smoothness     0.170581
# 34   mean smoothness      mean texture    -0.023389
# 35      mean texture   mean smoothness    -0.023389

# %%
sns.pairplot(wf)
plt.show()
